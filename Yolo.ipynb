# %% [markdown]
# <a href="https://colab.research.google.com/github/Oluwadara17/Computer-Vision/blob/main/Yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Detection**

# %%
# !mkdir -p images
# !wget -O images/1.jpg https://ultralytics.com/images/bus.jpg
# Out:
# --2026-06-11 14:20:37--  https://ultralytics.com/images/bus.jpg
# Resolving ultralytics.com (ultralytics.com)... 216.150.1.1
# Connecting to ultralytics.com (ultralytics.com)|216.150.1.1|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://www.ultralytics.com/images/bus.jpg [following]
# --2026-06-11 14:20:37--  https://www.ultralytics.com/images/bus.jpg
# Resolving www.ultralytics.com (www.ultralytics.com)... 216.150.1.129, 216.150.16.129
# Connecting to www.ultralytics.com (www.ultralytics.com)|216.150.1.129|:443... connected.
# HTTP request sent, awaiting response... 308 Permanent Redirect
# Location: https://github.com/ultralytics/assets/releases/download/v0.0.0/bus.jpg [following]
# --2026-06-11 14:20:37--  https://github.com/ultralytics/assets/releases/download/v0.0.0/bus.jpg
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/images/1.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images/1.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 352.0ms
# Speed: 20.0ms preprocess, 352.0ms inference, 46.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # **Segmentation**

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="images/1.jpg"
# Out:
# ...
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/images/1.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 445.9ms
# Speed: 9.6ms preprocess, 445.9ms inference, 19.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
results = model.predict(source="images/1.jpg", save=True)
# Out:
# image 1/1 /content/images/1.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 285.5ms
# Speed: 6.5ms preprocess, 285.5ms inference, 16.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/segment/predict-2

# %% [markdown]
# # **Classification**

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="images/1.jpg"
# Out:
# ...
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# image 1/1 /content/images/1.jpg: 224x224 minibus 0.50, police_van 0.29, trolleybus 0.05, golfcart 0.02, jinrikisha 0.02, 30.1ms
# Speed: 27.2ms preprocess, 30.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install ultralytics

from IPython.display import clear_output
clear_output()
# !yolo checks
# import ultralytics
# ultralytics.checks()
# Out:
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 20.4/107.7 GB disk)
#
# OS                     Linux-6.6.122+-x86_64-with-glibc2.35
# Environment            Colab
# Python                 3.12.13
# Install                pip
# Path                   /usr/local/lib/python3.12/dist-packages/ultralytics
# RAM                    12.67 GB
# Disk                   20.4/107.7 GB
# CPU                    Intel Xeon CPU @ 2.20GHz
# CPU count              2
# GPU                    None
# GPU count              None
# CUDA                   None
#
# numpy                  ✅ 2.0.2>=1.23.0
# matplotlib             ✅ 3.10.0>=3.3.0
# opencv-python          ✅ 4.13.0.92>=4.6.0
# pillow                 ✅ 11.3.0>=7.1.2
# pyyaml                 ✅ 6.0.3>=5.3.1
# requests               ✅ 2.32.4>=2.23.0
# scipy                  ✅ 1.16.3>=1.4.1
# torch                  ✅ 2.11.0+cpu>=1.8.0
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
  # load a pretrained model (recommended for training)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="https://media.roboflow.com/notebooks/examples/dog.jpeg"
# Out:
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 183.8ms
# Speed: 7.7ms preprocess, 183.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /content/runs/detect/predict-2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/dog.jpeg', height=600 ,width=600)

# %%
Image(filename="/content/runs/detect/predict-2/dog.jpg", height=600 ,width=600)

# %%
model =YOLO('/content/yolov8n.pt')
results= model.predict(source ='https://media.roboflow.com/notebooks/examples/dog.jpeg')
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 178.3ms
# Speed: 3.5ms preprocess, 178.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="oIzV5aN6DC8WBGFB3Ouj") # Extracted API key from your URL
project = rf.workspace().project("football-players-afjjc")
dataset = project.version(3).download("yolov8") # Replaced 'YOUR_VERSION' with '3'
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 101.5 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Football-Players-3 in yolov8:: 100%|██████████| 93/93 [00:00<00:00, 4469.64it/s]

# %% [markdown]
# Custom Training

# %%
# !yolo task=detect mode=train model =yolov8s.pt data= {dataset.location}/data.yaml epochs=15 imgsz=640
# Out:
# ...
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !ls /content/Football-Players-3/train
# Out:
# images	labels	labels.cache

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# Validate Custom Model (data)

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1430.3±299.0 MB/s, size: 67.1 KB)
# val: Scanning /content/Football-Players-3/valid/labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7 599.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0s/it 6.0s
#                    all          7         41      0.955      0.822      0.904      0.777
#       Football-Players          7         36          1      0.643      0.814      0.654
#                   ball          5          5      0.911          1      0.995        0.9
# Speed: 8.4ms preprocess, 756.7ms inference, 0.0ms loss, 85.6ms postprocess per image
# Results saved to /content/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Inference custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics 8.4.65 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/4 /content/Football-Players-3/test/images/istockphoto-1480045500-1024x1024_jpg.rf.ae4b09b553f695fb149d641b53ad8ac0.jpg: 640x640 3 Football-Playerss, 1 ball, 1072.8ms
# image 2/4 /content/Football-Players-3/test/images/suggested-ECBgDu1ucfgDVz3Ys27W_jpg.rf.637b5fc06f9dd5b17c2aca61814ee6cf.jpg: 640x640 5 Football-Playerss, 882.6ms
# image 3/4 /content/Football-Players-3/test/images/suggested-JBK49EDoW7PPFfmztfxo_jpg.rf.d5817dd88219d39d7bbfd9be43de7fba.jpg: 640x640 4 Football-Playerss, 2 balls, 684.2ms
# image 4/4 /content/Football-Players-3/test/images/suggested-R4KOE1tA330fHPxAKJaj_jpg.rf.3842a0ae0387895bc9fda2710d88ab09.jpg: 640x640 5 Football-Playerss, 1 ball, 678.4ms
# Speed: 4.7ms preprocess, 829.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ...

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.4.65, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the roboflow SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
import time
import sys

model = None
retries = 10
while model is None and retries > 0:
    model = project.version(dataset.version).model
    if model is None:
        print("Model deployment is still loading. Waiting 30 seconds...", file=sys.stderr)
        time.sleep(30)
        retries -= 1
    else:
        print("Model loaded successfully.")

if model is None:
    raise AssertionError("Model deployment timed out or failed to load after multiple retries.")

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# Model loaded successfully.
# running inference on istockphoto-1480045500-1024x1024_jpg.rf.ae4b09b553f695fb149d641b53ad8ac0.jpg
# {'predictions': [{'x': 446,
#    'y': 548,
#    'width': 44,
#    'height': 67,
#    'confidence': 0.9870229363441467,
#    'class': 'ball',
#    'class_id': 2,
#    'detection_id': '80b4c834-b16f-4fa4-8fba-640b7ef2ffaf',
#    'image_path': '/content/Football-Players-3/test/images/istockphoto-1480045500-1024x1024_jpg.rf.ae4b09b553f695fb149d641b53ad8ac0.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 434,
#    'y': 323,
#    'width': 88,
#    'height': 485,
#    'confidence': 0.9854229688644409,
#    'class': 'Football-Players',
#    'class_id': 0,
#    'detection_id': 'c7fe059e-633f-433d-8ae9-b81fc1ab6f60',
#    'image_path': '/content/Football-Players-3/test/images/istockphoto-1480045500-1024x1024_jpg.rf.ae4b09b553f695fb149d641b53ad8ac0.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 345,
#    'y': 340,
#    'width': 122,
# ...
